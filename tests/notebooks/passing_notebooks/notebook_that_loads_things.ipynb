# %%
import numpy as np

# %%
x = 2*np.pi*np.arange(1, 200)/200.
y = np.sin(x)

# %%
# np.save('x', x)
# np.save('y', y)

# %%
x1 = np.load('x.npy')
y1 = np.load('y.npy')

# %%
assert(np.all(x == x1))
assert(np.all(y == y1))
